# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from collections import OrderedDict
import os
import warnings
warnings.filterwarnings('ignore')
figsize=(10,6)
ylim=(0,1010)

# %%
def show_config(file_path):
    df_config = pd.read_csv(file_path, delimiter=':', header=None)
    df_config.columns = ['Parameters', 'Settings']
    print df_config
    #return the goal reward value for problem
    return df_config['Settings'].iloc[-1]

def plot_training(file_path, goal, ylim=ylim):
    df_pole = pd.read_csv(file_path, delim_whitespace=True, index_col=0)
    print '-----Training Data-----'
    print 'Max Average Reward:', df_pole.max()[1], 'Episode:', df_pole.idxmax()[1]
    print 'Max Episode Reward:', df_pole.max()[0], 'Episode:', df_pole.idxmax()[0]
    print 'Min Episode Reward:', df_pole.min()[0], 'Episode:', df_pole.idxmin()[0]
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_color_cycle(['blue', 'red', 'green'])
    plt.title("Training Episodes")
    plt.plot(df_pole['reward'], label='Episode Reward')
    plt.plot(df_pole['average_reward'], label='Average of Last 100 Episodes')
    plt.plot([0, df_pole.shape[0]], [goal, goal], label='Average Reward Goal Value')
    plt.xlim([0,df_pole.shape[0]])
    plt.ylim(ylim)
    ax.lines[-2].set_linewidth(2)
    plt.legend(loc='upper left')
    plt.show()
    
    
def plot_testing(file_path, goal, ylim=ylim):
    df_pole = pd.read_csv(file_path, delim_whitespace=True, index_col=0)
    print '-----Testing Data-----'
    print 'Average Reward:', df_pole['reward'].mean()
    #print 'Final Average Reward:', df_pole['average'].iloc[-1], 'Episode:', df_pole.index[-1]
    print 'Max Episode Reward:', df_pole.max()[0], 'Episode:', df_pole.idxmax()[0]
    print 'Min Episode Reward:', df_pole.min()[0], 'Episode:', df_pole.idxmin()[0]
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_color_cycle(['blue', 'red', 'green'])
    plt.title("Testing Episodes")
    plt.plot(df_pole['reward'], label='Episode Reward')
    plt.plot([0, df_pole.shape[0]], [df_pole['reward'].mean(), df_pole['reward'].mean()], label='Average Reward')
    plt.plot([0, df_pole.shape[0]], [goal, goal], label='Average Reward Goal Value')
    plt.xlim([0,df_pole.shape[0]])
    plt.ylim(ylim)
    ax.lines[-2].set_linewidth(2)
    plt.legend(loc='best')
    plt.show()
    
#plot all the training runs for a particular problem version
def plot_train_runs(file_dir, goal, figsize=figsize, xlim=None, ylim=None):
    files = os.listdir(file_dir)
    df_trains = []
    for f in files:
        if '.train' in f:
            df_trains.append(pd.read_csv(file_dir + f, delim_whitespace=True, index_col=0))
    fig, ax = plt.subplots(nrows=3, ncols=2, figsize=figsize)
    axs = ax.ravel()
    #dummy plot to clear out the top left subplot to place the legend
    for i in range(0, 1):
        axs[i+1].set_color_cycle(['red', 'blue', 'green'])
        df = df_trains[0]
        x_end = df.shape[0]
        ttl = 'Dummy Plot'
        axs[i].plot(df['average_reward'], label='Episode Average Reward')
        axs[i].plot(df['reward'], label='Episode Reward', alpha=0.2)
        axs[i].plot([0, x_end], [goal, goal], label='Goal Average Reward')
        axs[i].set_xlim((0,x_end))
        axs[i].set_ylim(ylim)
        axs[i].title.set_text(ttl)
    for i, df in enumerate(df_trains):
        axs[i+1].set_color_cycle(['red', 'blue', 'green'])
        x_end = df.shape[0]
        ttl = 'Training Run ' + str(i+1)
        axs[i+1].plot(df['average_reward'], label='Episode Average Reward')
        axs[i+1].plot(df['reward'], label='Episode Reward', alpha=0.2)
        axs[i+1].plot([0, x_end], [goal, goal], label='Goal Average Reward')
        axs[i+1].set_xlim((0,x_end))
        axs[i+1].set_ylim(ylim)
        axs[i+1].title.set_text(ttl)
    plt.tight_layout(pad=2)
    axs[0].set_visible(False)
    plt.legend(bbox_to_anchor=(-0.3,3.25), fontsize=15)
    plt.show()
    
#plot all the testing runs for a particular problem version
def plot_test_runs(file_dir, goal, figsize=figsize, xlim=None, ylim=None):
    files = os.listdir(file_dir)
    df_trains = []
    for f in files:
        if '.test' in f:
            df_trains.append(pd.read_csv(file_dir + f, delim_whitespace=True, index_col=0))
    fig, ax = plt.subplots(nrows=3, ncols=2, figsize=figsize)
    axs = ax.ravel()
    #dummy plot to clear out the top left subplot to place the legend
    for i in range(0, 1):
        axs[i+1].set_color_cycle(['blue', 'green'])
        df = df_trains[0]
        x_end = df.shape[0]
        ttl = 'Dummy Plot'
        axs[i].plot(df['reward'], label='Episode Reward', alpha=1)
        axs[i].plot([0, x_end], [goal, goal], label='Goal Average Reward')
        axs[i].set_xlim((0,x_end))
        axs[i].set_ylim(ylim)
        axs[i].title.set_text(ttl)
    for i, df in enumerate(df_trains):
        axs[i+1].set_color_cycle(['blue', 'green'])
        x_end = df.shape[0]
        ttl = 'Testing Run ' + str(i+1)
        axs[i+1].plot(df['reward'], label='Episode Reward', alpha=1)
        axs[i+1].plot([0, x_end], [goal, goal], label='Goal Average Reward')
        axs[i+1].set_xlim((0,x_end))
        axs[i+1].set_ylim(ylim)
        axs[i+1].title.set_text(ttl)
    plt.tight_layout(pad=2)
    axs[0].set_visible(False)
    plt.legend(bbox_to_anchor=(-0.3,3.25), fontsize=15)
    plt.show()

# %% [markdown]
# <h2>DRQN Cartpole Modified All Training Runs</h2>

# %%
plot_train_runs('Data/', 400, (14,10), None, (0,420))

# %% [markdown]
# <h2>DRQN Cartpole Modified All Test Runs</h2>

# %%
plot_test_runs('Data/', 400, (14,10), None, (0,102))

# %% [markdown]
# <h2>DRQN Cartpole Modified Run #1</h2>

# %%
goal = show_config('Data/Run_0.config')
plot_training('Data/Run_0.train', goal)
plot_testing('Data/Run_0.test', goal)
# Out:
#                      Parameters     Settings
# 0                     Save Path   Data/Run_0
# 1             Training Episodes         5000
# 2                Training Steps         1000
# 3              Testing Episodes          100
# 4                 Testing Steps         1000
# 5                   Memory Size         5000
# 6        Memory Episode Samples            8
# 7           Memory Step Samples            8
# 8        Start Training Episode          100
# 9        Target Copy Iterations          250
# 10      Target Copy Start Steps            0
# 11              Future Discount         0.99
# 12              Epsilon Minimum       0.0001
# 13              Epsilon Maximum          0.9
# 14                Epsilon Decay          0.9
# 15                Learning Rate       0.0005
# 16          Learning Rate Decay          0.8
# 17  Learning Rate Decay Episode          500
# 18                  LSTM Unroll            1
# 19                    Optimizer         adam
# 20                 Layer 1 Size          512
# 21                 Layer 2 Size          256
# 22           Layer 1 Activation         tanh
# 23           Layer 2 Activation         tanh
# 24                Training Goal        400.0
# -----Training Data-----
# Max Average Reward: 401.69 Episode: 1096
# Max Episode Reward: 1000.0 Episode: 339
# Min Episode Reward: 8.0 Episode: 109
# -----Testing Data-----
# Average Reward: 317.09
# Max Episode Reward: 1000.0 Episode: 30
# Min Episode Reward: 152.0 Episode: 33

# %% [markdown]
# <h2>DRQN Cartpole Modified Run #2</h2>

# %%
goal = show_config('Data/Run_1.config')
plot_training('Data/Run_1.train', goal)
plot_testing('Data/Run_1.test', goal)
# Out:
#                      Parameters     Settings
# 0                     Save Path   Data/Run_1
# 1             Training Episodes         5000
# 2                Training Steps         1000
# 3              Testing Episodes          100
# 4                 Testing Steps         1000
# 5                   Memory Size         5000
# 6        Memory Episode Samples            8
# 7           Memory Step Samples            8
# 8        Start Training Episode          100
# 9        Target Copy Iterations          250
# 10      Target Copy Start Steps            0
# 11              Future Discount         0.99
# 12              Epsilon Minimum       0.0001
# 13              Epsilon Maximum          0.9
# 14                Epsilon Decay          0.9
# 15                Learning Rate       0.0005
# 16          Learning Rate Decay          0.8
# 17  Learning Rate Decay Episode          500
# 18                  LSTM Unroll            1
# 19                    Optimizer         adam
# 20                 Layer 1 Size          512
# 21                 Layer 2 Size          256
# 22           Layer 1 Activation         tanh
# 23           Layer 2 Activation         tanh
# 24                Training Goal        400.0
# -----Training Data-----
# Max Average Reward: 402.96 Episode: 523
# Max Episode Reward: 1000.0 Episode: 459
# Min Episode Reward: 8.0 Episode: 107
# -----Testing Data-----
# Average Reward: 402.06
# Max Episode Reward: 873.0 Episode: 89
# Min Episode Reward: 188.0 Episode: 4

# %% [markdown]
# <h2>DRQN Cartpole Modified Run #3</h2>

# %%
goal = show_config('Data/Run_2.config')
plot_training('Data/Run_2.train', goal)
plot_testing('Data/Run_2.test', goal)
# Out:
#                      Parameters     Settings
# 0                     Save Path   Data/Run_2
# 1             Training Episodes         5000
# 2                Training Steps         1000
# 3              Testing Episodes          100
# 4                 Testing Steps         1000
# 5                   Memory Size         5000
# 6        Memory Episode Samples            8
# 7           Memory Step Samples            8
# 8        Start Training Episode          100
# 9        Target Copy Iterations          250
# 10      Target Copy Start Steps            0
# 11              Future Discount         0.99
# 12              Epsilon Minimum       0.0001
# 13              Epsilon Maximum          0.9
# 14                Epsilon Decay          0.9
# 15                Learning Rate       0.0005
# 16          Learning Rate Decay          0.8
# 17  Learning Rate Decay Episode          500
# 18                  LSTM Unroll            1
# 19                    Optimizer         adam
# 20                 Layer 1 Size          512
# 21                 Layer 2 Size          256
# 22           Layer 1 Activation         tanh
# 23           Layer 2 Activation         tanh
# 24                Training Goal        400.0
# -----Training Data-----
# Max Average Reward: 402.66 Episode: 419
# Max Episode Reward: 1000.0 Episode: 327
# Min Episode Reward: 8.0 Episode: 101
# -----Testing Data-----
# Average Reward: 767.08
# Max Episode Reward: 1000.0 Episode: 2
# Min Episode Reward: 283.0 Episode: 11

# %% [markdown]
# <h2>DRQN Cartpole Modified Run #4</h2>

# %%
goal = show_config('Data/Run_3.config')
plot_training('Data/Run_3.train', goal)
plot_testing('Data/Run_3.test', goal)
# Out:
#                      Parameters     Settings
# 0                     Save Path   Data/Run_3
# 1             Training Episodes         5000
# 2                Training Steps         1000
# 3              Testing Episodes          100
# 4                 Testing Steps         1000
# 5                   Memory Size         5000
# 6        Memory Episode Samples            8
# 7           Memory Step Samples            8
# 8        Start Training Episode          100
# 9        Target Copy Iterations          250
# 10      Target Copy Start Steps            0
# 11              Future Discount         0.99
# 12              Epsilon Minimum       0.0001
# 13              Epsilon Maximum          0.9
# 14                Epsilon Decay          0.9
# 15                Learning Rate       0.0005
# 16          Learning Rate Decay          0.8
# 17  Learning Rate Decay Episode          500
# 18                  LSTM Unroll            1
# 19                    Optimizer         adam
# 20                 Layer 1 Size          512
# 21                 Layer 2 Size          256
# 22           Layer 1 Activation         tanh
# 23           Layer 2 Activation         tanh
# 24                Training Goal        400.0
# -----Training Data-----
# Max Average Reward: 405.29 Episode: 462
# Max Episode Reward: 1000.0 Episode: 252
# Min Episode Reward: 8.0 Episode: 103
# -----Testing Data-----
# Average Reward: 227.82
# Max Episode Reward: 778.0 Episode: 91
# Min Episode Reward: 137.0 Episode: 67

# %% [markdown]
# <h2>DRQN Cartpole Modified Run #5</h2>

# %%
goal = show_config('Data/Run_4.config')
plot_training('Data/Run_4.train', goal)
plot_testing('Data/Run_4.test', goal)
# Out:
#                      Parameters     Settings
# 0                     Save Path   Data/Run_4
# 1             Training Episodes         5000
# 2                Training Steps         1000
# 3              Testing Episodes          100
# 4                 Testing Steps         1000
# 5                   Memory Size         5000
# 6        Memory Episode Samples            8
# 7           Memory Step Samples            8
# 8        Start Training Episode          100
# 9        Target Copy Iterations          250
# 10      Target Copy Start Steps            0
# 11              Future Discount         0.99
# 12              Epsilon Minimum       0.0001
# 13              Epsilon Maximum          0.9
# 14                Epsilon Decay          0.9
# 15                Learning Rate       0.0005
# 16          Learning Rate Decay          0.8
# 17  Learning Rate Decay Episode          500
# 18                  LSTM Unroll            1
# 19                    Optimizer         adam
# 20                 Layer 1 Size          512
# 21                 Layer 2 Size          256
# 22           Layer 1 Activation         tanh
# 23           Layer 2 Activation         tanh
# 24                Training Goal        400.0
# -----Training Data-----
# Max Average Reward: 400.92 Episode: 390
# Max Episode Reward: 1000.0 Episode: 238
# Min Episode Reward: 8.0 Episode: 104
# -----Testing Data-----
# Average Reward: 525.37
# Max Episode Reward: 1000.0 Episode: 39
# Min Episode Reward: 302.0 Episode: 64
